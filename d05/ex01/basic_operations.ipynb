# %% [markdown]
# ## Imports

# %% [markdown]
# Imports

# %%
import pandas as pd

# %% [markdown]
# ## Reading

# %% [markdown]
# Here we read data from file to pandas...

# %%
df = pd.read_csv('../data/feed-views.log', 
                 sep='\t', 
                 names=('datetime','user'), 
                 parse_dates=['datetime'])

# %% [markdown]
# ...and print the dataframe samples

# %%
df.head()
# Out:
#                     datetime   user
# 0 2020-04-17 12:01:08.463179  artem
# 1 2020-04-17 12:01:23.743946  artem
# 2 2020-04-17 12:27:30.646665  artem
# 3 2020-04-17 12:35:44.884757  artem
# 4 2020-04-17 12:35:52.735016  artem

# %%
df.tail()
# Out:
#                        datetime       user
# 1071 2020-05-21 18:45:20.441142  valentina
# 1072 2020-05-21 23:03:06.457819      maxim
# 1073 2020-05-21 23:23:49.995349      pavel
# 1074 2020-05-21 23:49:22.386789      artem
# 1075 2020-05-22 10:36:14.662600      artem

# %% [markdown]
# ## Make new cols from datetime

# %% [markdown]
# Separately work with each collumn...

# %%
df['year'] = pd.DatetimeIndex(df['datetime']).year
df['month'] = pd.DatetimeIndex(df['datetime']).month
df['day'] = pd.DatetimeIndex(df['datetime']).day
df['hour'] = pd.DatetimeIndex(df['datetime']).hour
df['minute'] = pd.DatetimeIndex(df['datetime']).minute
df['second'] = pd.DatetimeIndex(df['datetime']).second

# %% [markdown]
# ...and print the dataframe

# %%
df
# Out:
#                        datetime       user  year  month  day  hour  minute  \
# 0    2020-04-17 12:01:08.463179      artem  2020      4   17    12       1
# 1    2020-04-17 12:01:23.743946      artem  2020      4   17    12       1
# 2    2020-04-17 12:27:30.646665      artem  2020      4   17    12      27
# 3    2020-04-17 12:35:44.884757      artem  2020      4   17    12      35
# 4    2020-04-17 12:35:52.735016      artem  2020      4   17    12      35
# ...                         ...        ...   ...    ...  ...   ...     ...
# 1071 2020-05-21 18:45:20.441142  valentina  2020      5   21    18      45
# 1072 2020-05-21 23:03:06.457819      maxim  2020      5   21    23       3
# 1073 2020-05-21 23:23:49.995349      pavel  2020      5   21    23      23
# 1074 2020-05-21 23:49:22.386789      artem  2020      5   21    23      49
# 1075 2020-05-22 10:36:14.662600      artem  2020      5   22    10      36
#
#       second
# 0          8
# 1         23
# 2         30
# 3         44
# 4         52
# ...      ...
# 1071      20
# 1072       6
# 1073      49
# 1074      22
# 1075      14
#
# [1076 rows x 8 columns]

# %% [markdown]
# ## Insert new daytime column

# %% [markdown]
# Do it with pd.cut...

# %%
labels = ['night', 
          'early morning', 
          'morning', 'afternoon', 
          'early evening', 
          'evening']
bins = [-1, 3, 6, 10, 16, 19, 24]
df['daytime'] = pd.cut(df.hour, bins=bins, labels=labels)

# %% [markdown]
# ...and print some random sector

# %%
df[20:40]
# Out:
#                      datetime        user  year  month  day  hour  minute  \
# 20 2020-04-18 12:49:16.684426       artem  2020      4   18    12      49
# 21 2020-04-18 17:45:27.234821       artem  2020      4   18    17      45
# 22 2020-04-18 18:14:53.813657  konstantin  2020      4   18    18      14
# 23 2020-04-18 18:20:05.419381  konstantin  2020      4   18    18      20
# 24 2020-04-18 18:20:32.196892  konstantin  2020      4   18    18      20
# 25 2020-04-18 18:20:37.860671  konstantin  2020      4   18    18      20
# 26 2020-04-18 18:24:59.632526  konstantin  2020      4   18    18      24
# 27 2020-04-18 18:50:15.409435  konstantin  2020      4   18    18      50
# 28 2020-04-18 19:20:27.487265       artem  2020      4   18    19      20
# 29 2020-04-18 21:01:33.970629  konstantin  2020      4   18    21       1
# 30 2020-04-18 21:06:16.842414  konstantin  2020      4   18    21       6
# 31 2020-04-18 21:14:43.989325  konstantin  2020      4   18    21      14
# 32 2020-04-18 21:33:35.285278  konstantin  2020      4   18    21      33
# 33 2020-04-18 21:36:38.965506  konstantin  2020      4   18    21      36
# 34 2020-04-18 21:46:57.879404  konstantin  2020      4   18    21      46
# 35 2020-04-18 21:47:27.939041  konstantin  2020      4   18    21      47
# 36 2020-04-18 21:58:49.438700  konstantin  2020      4   18    21      58
# 37 2020-04-18 22:38:29.435265  konstantin  2020      4   18    22      38
# 38 2020-04-18 23:06:34.198911  konstantin  2020      4   18    23       6
# 39 2020-04-18 23:40:32.666884       artem  2020      4   18    23      40
#
#     second        daytime
# 20      16      afternoon
# 21      27  early evening
# 22      53  early evening
# 23       5  early evening
# 24      32  early evening
# 25      37  early evening
# 26      59  early evening
# 27      15  early evening
# 28      27  early evening
# 29      33        evening
# 30      16        evening
# 31      43        evening
# 32      35        evening
# 33      38        evening
# 34      57        evening
# 35      27        evening
# 36      49        evening
# 37      29        evening
# 38      34        evening
# 39      32        evening

# %% [markdown]
# ## Assign User as index
# in df

# %%
df.set_index('user', inplace=True)

# %% [markdown]
# and print df

# %%
df.head()
# Out:
#                         datetime  year  month  day  hour  minute  second  \
# user
# artem 2020-04-17 12:01:08.463179  2020      4   17    12       1       8
# artem 2020-04-17 12:01:23.743946  2020      4   17    12       1      23
# artem 2020-04-17 12:27:30.646665  2020      4   17    12      27      30
# artem 2020-04-17 12:35:44.884757  2020      4   17    12      35      44
# artem 2020-04-17 12:35:52.735016  2020      4   17    12      35      52
#
#          daytime
# user
# artem  afternoon
# artem  afternoon
# artem  afternoon
# artem  afternoon
# artem  afternoon

# %%
df.tail()
# Out:
#                             datetime  year  month  day  hour  minute  second  \
# user
# valentina 2020-05-21 18:45:20.441142  2020      5   21    18      45      20
# maxim     2020-05-21 23:03:06.457819  2020      5   21    23       3       6
# pavel     2020-05-21 23:23:49.995349  2020      5   21    23      23      49
# artem     2020-05-21 23:49:22.386789  2020      5   21    23      49      22
# artem     2020-05-22 10:36:14.662600  2020      5   22    10      36      14
#
#                  daytime
# user
# valentina  early evening
# maxim            evening
# pavel            evening
# artem            evening
# artem            morning

# %% [markdown]
# ## Calculating stats by count and value_counts

# %% [markdown]
# Number of elements in dataframe:

# %%
df.count()
# Out:
# datetime    1076
# year        1076
# month       1076
# day         1076
# hour        1076
# minute      1076
# second      1076
# daytime     1076
# dtype: int64

# %%
df.value_counts('daytime')
# Out:
# daytime
# evening          509
# afternoon        252
# early evening    145
# night            129
# morning           36
# early morning      5
# dtype: int64

# %% [markdown]
# ## Sort df by hour, min and sec
# In ascending order simultaniously

# %%
df.sort_values(by=['hour', 'minute', 'second'], inplace=True)

# %%
df
# Out:
#                             datetime  year  month  day  hour  minute  second  \
# user
# valentina 2020-05-15 00:00:13.222265  2020      5   15     0       0      13
# valentina 2020-05-15 00:01:05.153738  2020      5   15     0       1       5
# pavel     2020-05-12 00:01:27.764025  2020      5   12     0       1      27
# pavel     2020-05-12 00:01:38.444917  2020      5   12     0       1      38
# pavel     2020-05-12 00:01:55.395042  2020      5   12     0       1      55
# ...                              ...   ...    ...  ...   ...     ...     ...
# artem     2020-05-21 23:49:22.386789  2020      5   21    23      49      22
# anatoliy  2020-05-09 23:53:55.599821  2020      5    9    23      53      55
# pavel     2020-05-09 23:54:54.260791  2020      5    9    23      54      54
# valentina 2020-05-14 23:58:56.754866  2020      5   14    23      58      56
# alexander 2020-05-14 23:59:38.758438  2020      5   14    23      59      38
#
#            daytime
# user
# valentina    night
# valentina    night
# pavel        night
# pavel        night
# pavel        night
# ...            ...
# artem      evening
# anatoliy   evening
# pavel      evening
# valentina  evening
# alexander  evening
#
# [1076 rows x 8 columns]

# %% [markdown]
# ## Using min / max / mode

# %% [markdown]
# Calculate the maximum of hour for the rows where the time of day is night

# %%
df.hour.loc[df.daytime == 'night'].max()
# Out:
# 3

# %% [markdown]
# Calculate the minimum of hour for the rows where the time of day is morning

# %%
df.hour.loc[df.daytime == 'morning'].min()
# Out:
# 8

# %% [markdown]
# Find out who visited the page at those hours (make one example from that)

# %%
df.loc[df.hour == df.hour.loc[df.daytime == 'night'].max()]
# Out:
#                              datetime  year  month  day  hour  minute  second  \
# user
# konstantin 2020-04-19 03:23:35.471598  2020      4   19     3      23      35
# konstantin 2020-04-19 03:23:55.473926  2020      4   19     3      23      55
# konstantin 2020-04-19 03:33:07.757714  2020      4   19     3      33       7
#
#            daytime
# user
# konstantin   night
# konstantin   night
# konstantin   night

# %%
df.loc[df.hour == df.hour.loc[df.daytime == 'morning'].min()]
# Out:
#                             datetime  year  month  day  hour  minute  second  \
# user
# alexander 2020-05-15 08:16:03.918402  2020      5   15     8      16       3
# alexander 2020-05-15 08:35:01.471463  2020      5   15     8      35       1
#
#            daytime
# user
# alexander  morning
# alexander  morning

# %% [markdown]
# Calculate the mode for the hour and daytime

# %%
df.hour.mode()
# Out:
# 0    22
# Name: hour, dtype: int64

# %%
df.daytime.mode()
# Out:
# 0    evening
# Name: daytime, dtype: category
# Categories (6, object): ['night' < 'early morning' < 'morning' < 'afternoon' < 'early evening' < 'evening']

# %% [markdown]
# ## Using nsmallest() and nlargest()

# %% [markdown]
# to show the 3 earliest hours in the morning and the corresponding usernames and the
# 3 latest hours and the usernames

# %%
df.hour.loc[df.daytime == 'morning'].nlargest(3)
# Out:
# user
# konstantin    10
# maxim         10
# maxim         10
# Name: hour, dtype: int64

# %%
df.hour.loc[df.daytime == 'morning'].nsmallest(3)
# Out:
# user
# alexander    8
# alexander    8
# alexander    9
# Name: hour, dtype: int64

# %% [markdown]
# ## Basic stats with describe()

# %%
descriptions = df.describe()

# %%
descriptions
# Out:
#          year        month          day         hour       minute       second
# count  1076.0  1076.000000  1076.000000  1076.000000  1076.000000  1076.000000
# mean   2020.0     4.870818    13.552974    16.249071    29.629182    29.500929
# std       0.0     0.335557     4.906567     6.955490    17.689388    17.405506
# min    2020.0     4.000000     1.000000     0.000000     0.000000     0.000000
# 25%    2020.0     5.000000    11.000000    13.000000    14.000000    14.000000
# 50%    2020.0     5.000000    13.000000    19.000000    29.000000    30.000000
# 75%    2020.0     5.000000    15.000000    22.000000    46.000000    45.000000
# max    2020.0     5.000000    30.000000    23.000000    59.000000    59.000000

# %% [markdown]
# Calculate the interquartile range for the hour by extracting values from the result of the describe() method

# %%
iqr = descriptions.hour['75%'] - descriptions.hour['25%']

# %%
iqr
# Out:
# 9.0
